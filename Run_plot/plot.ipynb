# %%
from util import compute_variance_and_plot, plot_variance_for_dataset,plot_correlation_heatmap,load_and_compute_average_correlation_filtered,plot_min_heatmap,load_and_final_df

# %%
preprocess_folders = [
    "align_entropy_5000_logfc",
    "align_entropy_sg_FC",
    "result_entropy_5000_FC_sg",
    'result_entropy_5000_logfc',
    'result_entropy_5000_sg_logfc',
    'result_entropy_sg_5000_FC',
    'result_exp_5000_logfc',
]
file_patterns = {
    "grea_KS_signperm_es": [f"grea_KS_signperm_es_{i}.csv" for i in range(1, 4)],
    "blitz": [f"blitz_{i}.csv" for i in range(1, 4)],
    "gseapy": [f"gseapy_{i}.csv" for i in range(1, 4)],
    "grea_KS_signperm_esd": [f"grea_KS_signperm_esd_{i}.csv" for i in range(1, 4)],
    "grea_KS_signgamma_es": [f"grea_KS_signgamma_es_{i}.csv" for i in range(1, 4)],
    "grea_KS_signgamma_esd": [f"grea_KS_signgamma_esd_{i}.csv" for i in range(1, 4)],
    "grea_RC_gamma_auc": [f"grea_RC_gamma_auc_{i}.csv" for i in range(1, 4)],
    "grea_RC_perm_AUC": [f"grea_RC_perm_AUC_{i}.csv" for i in range(1, 4)],
}

column_mapping = {
    "blitz": {"es_pval": "pval"},
    "gseapy": {"NES": "nes", "NOM p-val": "pval"},
    "default": {"es_pval": "pval", "esd_pval": "pval", "AUC_pval": "pval"}
}
method_name_mapping = {
        'align_entropy_5000_logfc_grea_KS_signperm_es':    'Perm-Exp_Entropy-ES',
       'align_entropy_sg_FC_grea_KS_signperm_es':    'Perm-Exp_SingleGene-ES',
       'result_entropy_5000_FC_sg_grea_KS_signperm_es':    'Perm-SingleGene-ES',
       'result_entropy_5000_logfc_grea_KS_signperm_es':    'Perm-Entropy-ES',
       'result_entropy_5000_sg_logfc_grea_KS_signperm_es':    'Perm-HVG_SingleGene-ES',
       'result_entropy_sg_5000_FC_grea_KS_signperm_es':    'Perm-SingleGene_HVG-ES',
       'result_exp_5000_logfc_grea_KS_signperm_es':    'Perm-EXP-ES',
       'align_entropy_5000_logfc_grea_KS_signperm_esd':    'Perm-Exp_Entropy-ESD',
       'align_entropy_sg_FC_grea_KS_signperm_esd':    'Perm-Exp_SingleGene-ESD',
       'result_entropy_5000_FC_sg_grea_KS_signperm_esd':    'Perm-SingleGene-ESD',
       'result_entropy_5000_logfc_grea_KS_signperm_esd':    'Perm-Entropy-ESD',
       'result_entropy_5000_sg_logfc_grea_KS_signperm_esd':    'Perm-HVG_SingleGene-ESD',
       'result_entropy_sg_5000_FC_grea_KS_signperm_esd':    'Perm-SingleGene_HVG-ESD',
       'result_exp_5000_logfc_grea_KS_signperm_esd':    'Perm-EXP-ESD',
       'align_entropy_5000_logfc_grea_RC_perm_AUC':    'Perm-Exp_Entropy-AUC',
       'align_entropy_sg_FC_grea_RC_perm_AUC':    'Perm-Exp_SingleGene-AUC',
       'result_entropy_5000_FC_sg_grea_RC_perm_AUC':    'Perm-SingleGene-AUC',
       'result_entropy_5000_logfc_grea_RC_perm_AUC':    'Perm-Entropy-AUC',
       'result_entropy_5000_sg_logfc_grea_RC_perm_AUC':    'Perm-HVG_SingleGene-AUC',
       'result_entropy_sg_5000_FC_grea_RC_perm_AUC':    'Perm-SingleGene_HVG-AUC',
       'result_exp_5000_logfc_grea_RC_perm_AUC':    'Perm-EXP-AUC',
        'align_entropy_5000_logfc_grea_KS_signgamma_es':    'Gamma-Exp_Entropy-ES',
       'align_entropy_sg_FC_grea_KS_signgamma_es':    'Gamma-Exp_SingleGene-ES',
       'result_entropy_5000_FC_sg_grea_KS_signgamma_es':    'Gamma-SingleGene-ES',
       'result_entropy_5000_logfc_grea_KS_signgamma_es':    'Gamma-Entropy-ES',
       'result_entropy_5000_sg_logfc_grea_KS_signgamma_es':    'Gamma-HVG_SingleGene-ES',
       'result_entropy_sg_5000_FC_grea_KS_signgamma_es':    'Gamma-SingleGene_HVG-ES',
       'result_exp_5000_logfc_grea_KS_signgamma_es':    'Gamma-EXP-ES',
       'align_entropy_5000_logfc_grea_KS_signgamma_esd':    'Gamma-Exp_Entropy-ESD',
       'align_entropy_sg_FC_grea_KS_signgamma_esd':    'Gamma-Exp_SingleGene-ESD',
       'result_entropy_5000_FC_sg_grea_KS_signgamma_esd':    'Gamma-SingleGene-ESD',
       'result_entropy_5000_logfc_grea_KS_signgamma_esd':    'Gamma-Entropy-ESD',
       'result_entropy_5000_sg_logfc_grea_KS_signgamma_esd':    'Gamma-HVG_SingleGene-ESD',
       'result_entropy_sg_5000_FC_grea_KS_signgamma_esd':    'Gamma-SingleGene_HVG-ESD',
       'result_exp_5000_logfc_grea_KS_signgamma_esd':    'Gamma-EXP-ESD',
       'align_entropy_5000_logfc_grea_RC_gamma_auc':    'Gamma-Exp_Entropy-AUC',
       'align_entropy_sg_FC_grea_RC_gamma_auc':    'Gamma-Exp_SingleGene-AUC',
       'result_entropy_5000_FC_sg_grea_RC_gamma_auc':    'Gamma-SingleGene-AUC',
       'result_entropy_5000_logfc_grea_RC_gamma_auc':    'Gamma-Entropy-AUC',
       'result_entropy_5000_sg_logfc_grea_RC_gamma_auc':    'Gamma-HVG_SingleGene-AUC',
       'result_entropy_sg_5000_FC_grea_RC_gamma_auc':    'Gamma-SingleGene_HVG-AUC',
       'result_exp_5000_logfc_grea_RC_gamma_auc':    'Gamma-EXP-AUC',
       'align_entropy_sg_FC_blitz':    'Exp_SingleGene-Blitz',
        'result_entropy_5000_FC_sg_blitz':    'SingleGene-Blitz',
       'result_entropy_5000_sg_logfc_blitz':    'HVG_SingleGene-Blitz',
       'result_entropy_sg_5000_FC_blitz':    'SingleGene_HVG-Blitz',
        'result_exp_5000_logfc_blitz':    'EXP-Blitz',
       'align_entropy_sg_FC_gseapy':    'Exp_SingleGene-GSEApy',
       'result_entropy_5000_FC_sg_gseapy':    'SingleGene-GSEApy',
       'result_entropy_5000_sg_logfc_gseapy':    'HVG_SingleGene-GSEApy',
       'result_entropy_sg_5000_FC_gseapy':    'SingleGene_HVG-GSEApy',
       'result_exp_5000_logfc_gseapy':    'EXP-GSEApy',

}
short_method_order = [
    'Perm-Exp_Entropy-ES',
    'Perm-Exp_SingleGene-ES',
    'Perm-SingleGene-ES',
    'Perm-Entropy-ES',
    'Perm-HVG_SingleGene-ES',
    'Perm-SingleGene_HVG-ES',
    'Perm-EXP-ES',
    'Gamma-Exp_Entropy-ES',
    'Gamma-Exp_SingleGene-ES',
    'Gamma-SingleGene-ES',
    'Gamma-Entropy-ES',
    'Gamma-HVG_SingleGene-ES',
    'Gamma-SingleGene_HVG-ES',
    'Gamma-EXP-ES',
    'Perm-Exp_Entropy-ESD',
    'Perm-Exp_SingleGene-ESD',
    'Perm-SingleGene-ESD',
    'Perm-Entropy-ESD',
    'Perm-HVG_SingleGene-ESD',
    'Perm-SingleGene_HVG-ESD',
    'Perm-EXP-ESD',
     'Gamma-Exp_Entropy-ESD',
    'Gamma-Exp_SingleGene-ESD',
    'Gamma-SingleGene-ESD',
    'Gamma-Entropy-ESD',
    'Gamma-HVG_SingleGene-ESD',
    'Gamma-SingleGene_HVG-ESD',
    'Gamma-EXP-ESD',
    'Perm-Exp_Entropy-AUC',
    'Perm-Exp_SingleGene-AUC',
    'Perm-SingleGene-AUC',
    'Perm-Entropy-AUC',
    'Perm-HVG_SingleGene-AUC',
    'Perm-SingleGene_HVG-AUC',
    'Perm-EXP-AUC',
    'Gamma-Exp_Entropy-AUC',
    'Gamma-Exp_SingleGene-AUC',
    'Gamma-SingleGene-AUC',
    'Gamma-Entropy-AUC',
    'Gamma-HVG_SingleGene-AUC',
    'Gamma-SingleGene_HVG-AUC',
    'Gamma-EXP-AUC',
    'Exp_SingleGene-Blitz',
    'SingleGene-Blitz',
    'HVG_SingleGene-Blitz',
    'SingleGene_HVG-Blitz',
    'EXP-Blitz',
    'Exp_SingleGene-GSEApy',
    'SingleGene-GSEApy',
    'HVG_SingleGene-GSEApy',
    'SingleGene_HVG-GSEApy',
    'EXP-GSEApy',
] 


label_colors = {
    'Perm-Exp_Entropy-ES':("#75bd42", "#e3f2d9"),  
    'Perm-Exp_SingleGene-ES': ("#f2ba02", "#e3f2d9"),
    'Perm-SingleGene-ES':("#30c0b4", "#e3f2d9"),
    'Perm-Entropy-ES':("#ee822f", "#e3f2d9"),
    'Perm-HVG_SingleGene-ES':("#e54c5e", "#e3f2d9"),
    'Perm-SingleGene_HVG-ES':("#4874cb", "#e3f2d9"),
    'Perm-EXP-ES':("#4a3535", "#e3f2d9"),
    'Gamma-Exp_Entropy-ES':("#75bd42","#fce6d5"),
    'Gamma-Exp_SingleGene-ES': ("#f2ba02", "#fce6d5"),
    'Gamma-SingleGene-ES':("#30c0b4", "#fce6d5"),
    'Gamma-Entropy-ES':("#ee822f","#fce6d5"),
    'Gamma-HVG_SingleGene-ES':("#e54c5e", "#fce6d5"),
    'Gamma-SingleGene_HVG-ES':("#4874cb","#fce6d5"),
    'Gamma-EXP-ES':("#4a3535", "#fce6d5"),
    'Perm-Exp_Entropy-ESD':("#75bd42","#d4f4f1"),
    'Perm-Exp_SingleGene-ESD': ("#f2ba02", "#d4f4f1"),
    'Perm-SingleGene-ESD':("#30c0b4", "#d4f4f1"),
    'Perm-Entropy-ESD':("#ee822f","#d4f4f1"),
    'Perm-HVG_SingleGene-ESD':("#e54c5e", "#d4f4f1"),
    'Perm-SingleGene_HVG-ESD':("#4874cb","#d4f4f1"),
    'Perm-EXP-ESD':("#4a3535", "#d4f4f1"),
    'Gamma-Exp_Entropy-ESD':("#75bd42","#fadbdf"),
    'Gamma-Exp_SingleGene-ESD': ("#f2ba02", "#fadbdf"),
    'Gamma-SingleGene-ESD':("#30c0b4", "#fadbdf"),
    'Gamma-Entropy-ESD':("#ee822f","#fadbdf"),
    'Gamma-HVG_SingleGene-ESD':("#e54c5e", "#fadbdf"),
    'Gamma-SingleGene_HVG-ESD':("#4874cb","#fadbdf"),
    'Gamma-EXP-ESD':("#4a3535", "#fadbdf"),
    'Perm-Exp_Entropy-AUC':("#75bd42","#dae3f5"),
    'Perm-Exp_SingleGene-AUC': ("#f2ba02", "#dae3f5"),
    'Perm-SingleGene-AUC':("#30c0b4", "#dae3f5"),
    'Perm-Entropy-AUC':("#ee822f","#dae3f5"),
    'Perm-HVG_SingleGene-AUC':("#e54c5e", "#dae3f5"),
    'Perm-SingleGene_HVG-AUC':("#4874cb","#dae3f5"),
    'Perm-EXP-AUC':("#4a3535", "#dae3f5"),
    'Gamma-Exp_Entropy-AUC':("#75bd42","#fff2ca"),
    'Gamma-Exp_SingleGene-AUC': ("#f2ba02", "#fff2ca"),
    'Gamma-SingleGene-AUC':("#30c0b4", "#fff2ca"),
    'Gamma-Entropy-AUC':("#ee822f","#fff2ca"),
    'Gamma-HVG_SingleGene-AUC':("#e54c5e", "#fff2ca"),
    'Gamma-SingleGene_HVG-AUC':("#4874cb","#fff2ca"),
    'Gamma-EXP-AUC':("#4a3535", "#fff2ca"),
    'Exp_SingleGene-Blitz':("#f2ba02", "#e9ddf6"),
    'SingleGene-Blitz':("#30c0b4", "#e9ddf6"),
    'HVG_SingleGene-Blitz':("#e54c5e", "#e9ddf6"),
    'SingleGene_HVG-Blitz':("#4874cb","#e9ddf6"),
    'EXP-Blitz':("#4a3535", "#e9ddf6"),
    'Exp_SingleGene-GSEApy':("#f2ba02", "#cef3c7"),
    'SingleGene-GSEApy':("#30c0b4", "#cef3c7"),
    'HVG_SingleGene-GSEApy':("#e54c5e", "#cef3c7"),
    'SingleGene_HVG-GSEApy':("#4874cb","#cef3c7"),
    'EXP-GSEApy':("#4a3535", "#cef3c7"),

}


base_result_dir = "../result"

# %% [markdown]
# ## Flu -- box plot

# %%
disease_folders = [
        "GSE52428_H1N1",
        "GSE52428_H3N2",
        "GSE73072_H1N1_DEE3",
        "GSE73072_H1N1_DEE4",
        "GSE73072_H3N2_DEE2",
        "GSE73072_H3N2_DEE5",
        "GSE73072_HRV_DUKE",
        "GSE73072_HRV_UVA",
        "GSE73072_RSV_DEE1",
    ]
df = compute_variance_and_plot(
    disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        base_data_dir=base_result_dir,
)
plot_variance_for_dataset(
    df=df,
    method_name_mapping=method_name_mapping,
    short_method_order=short_method_order,
    label_colors=label_colors,
    dataset_name="Flu",
    output_dir="out",
)

# %% [markdown]
# ## Cancer -- box plot

# %%
disease_folders = [
        "COAD_iia",
        "COAD_iv",
        "KIRC_iii",
        "KIRC_iv",
        "LUAD_iib",
        "LUAD_iv",
        "STAD_iiia",
        "STAD_iv",
        "THCA_iii",
        "THCA_iva",
    ]
df = compute_variance_and_plot(
    disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        base_data_dir=base_result_dir,
)
plot_variance_for_dataset(
    df=df,
    method_name_mapping=method_name_mapping,
    short_method_order=short_method_order,
    label_colors=label_colors,
    dataset_name="Cancer",
    output_dir="out",
)

# %% [markdown]
# ## Flu -- correlation heatmap

# %%
disease_folders = [
    "GSE52428_H1N1",
    "GSE52428_H3N2",
    "GSE73072_H1N1_DEE3",
    "GSE73072_H1N1_DEE4",
    "GSE73072_H3N2_DEE2",
    "GSE73072_H3N2_DEE5",
    "GSE73072_HRV_DUKE",
    "GSE73072_HRV_UVA",
    "GSE73072_RSV_DEE1",
    ]

correlation_df = load_and_compute_average_correlation_filtered(
        disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        short_method_order = short_method_order,
        method_name_mapping=method_name_mapping,
        base_data_dir=base_result_dir,
    )

plot_correlation_heatmap(
    correlation_df=correlation_df,
    short_method_order=short_method_order,
    label_colors=label_colors,
    output_dir="out",
    dataset_name="Flu"
)

# %% [markdown]
# ## Cancer -- correlation heatmap

# %%
disease_folders = [
        "COAD_iia",
        "COAD_iv",
        "KIRC_iii",
        "KIRC_iv",
        "LUAD_iib",
        "LUAD_iv",
        "STAD_iiia",
        "STAD_iv",
        "THCA_iii",
        "THCA_iva",
    ]

correlation_df = load_and_compute_average_correlation_filtered(
        disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        short_method_order = short_method_order,
        method_name_mapping=method_name_mapping,
        base_data_dir=base_result_dir,
    )

plot_correlation_heatmap(
    correlation_df=correlation_df,
    short_method_order=short_method_order,
    label_colors=label_colors,
    output_dir="out",
    dataset_name="Cancer"
)

# %% [markdown]
# ## Flu -- max -log10 p_val heatmap

# %%
disease_folders = [
    "GSE52428_H1N1",
    "GSE52428_H3N2",
    "GSE73072_H1N1_DEE3",
    "GSE73072_H1N1_DEE4",
    "GSE73072_H3N2_DEE2",
    "GSE73072_H3N2_DEE5",
    "GSE73072_HRV_DUKE",
    "GSE73072_HRV_UVA",
    "GSE73072_RSV_DEE1",
    ]

final_df = load_and_final_df(
        disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        short_method_order = short_method_order,
        method_name_mapping=method_name_mapping,
        base_data_dir=base_result_dir,
    )
plot_min_heatmap(
    log_df=final_df,
    label_colors=label_colors,
    output_dir="out",
    dataset_name="Flu",
)

# %% [markdown]
# ## Cancer -- max -log10 p_val heatmap

# %%
disease_folders = [
        "COAD_iia",
        "COAD_iv",
        "KIRC_iii",
        "KIRC_iv",
        "LUAD_iib",
        "LUAD_iv",
        "STAD_iiia",
        "STAD_iv",
        "THCA_iii",
        "THCA_iva",
    ]
final_df = load_and_final_df(
        disease_folders=disease_folders,
        preprocess_folders=preprocess_folders,
        file_patterns=file_patterns,
        column_mapping=column_mapping,
        short_method_order = short_method_order,
        method_name_mapping=method_name_mapping,
        base_data_dir=base_result_dir,
    )
plot_min_heatmap(
    log_df=final_df,
    label_colors=label_colors,
    output_dir="out",
    dataset_name="Cancer",
)
